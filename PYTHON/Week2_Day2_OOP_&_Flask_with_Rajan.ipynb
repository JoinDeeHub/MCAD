# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Let us Translate the Above Representation  in CODING

class Banker :

  salary = 5000           # variable in a class  is identified as Property

  def approveLoan(self):                   # this is Function in Python , it is created using def keyword.     syntax :      def  functionName() : code goes here.
    print('i approve Loans')



natrajan = Banker ()            # in this line we created the object. Syntax :    objectName = className ()


natrajan.approveLoan()         # in this line object is calling /executing the function.
# Out:
# i approve Loans

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Quick Activity :
# ----
#
# create a Class Dog .
#
# create a function inside class Bark() , print a message 'woof woof!'
#
#
# create an object of Dog say 'courage' and call the Bark function .

# %%
class Banker :

  salary = 5000

  def approveLoan(self):
    print('i approve Loans')



natrajan = Banker ()

# %%
print ( natrajan.salary )
# Out:
# 5000

# %%
natrajan.approveLoan()
# Out:
# i approve Loans

# %% [markdown]
# # post ☕ break topic
#
# Flask

# %%
data=[{"id":"17h","url":"https://cdn2.thecatapi.com/images/17h.jpg","width":500,"height":332},
 {"id":"234","url":"https://cdn2.thecatapi.com/images/234.jpg","width":604,"height":402},
  {"id":"3bv","url":"https://cdn2.thecatapi.com/images/3bv.jpg","width":600,"height":450},
   {"id":"4o7","url":"https://cdn2.thecatapi.com/images/4o7.jpg","width":500,"height":333},
    {"id":"5cc","url":"https://cdn2.thecatapi.com/images/5cc.jpg","width":470,"height":500},
     {"id":"5lo","url":"https://cdn2.thecatapi.com/images/5lo.jpg","width":480,"height":360},
      {"id":"bki","url":"https://cdn2.thecatapi.com/images/bki.jpg","width":375,"height":500},
       {"id":"bq1","url":"https://cdn2.thecatapi.com/images/bq1.jpg","width":1200,"height":900},{"id":"chh","url":"https://cdn2.thecatapi.com/images/chh.jpg","width":420,"height":630},{"id":"ehn","url":"https://cdn2.thecatapi.com/images/ehn.jpg","width":700,"height":700}]

# %%
for mydictionary in data :

  print( mydictionary['url'][-7:])
# Out:
# 17h.jpg
# 234.jpg
# 3bv.jpg
# 4o7.jpg
# 5cc.jpg
# 5lo.jpg
# bki.jpg
# bq1.jpg
# chh.jpg
# ehn.jpg
